# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
df = pd.read_csv("../Australian_Data_with_Latlong.csv")

# %%
df
# Out:
#             PERSONID  AGE  GENDER  ANYWORK  CARLICENCE  HHSTRUCTURE  HH_CARS  \
# 0      Y09H151315P01   40       2        1           1            4        0
# 1      Y09H151324P01   73       1        2           1            2        1
# 2      Y09H151340P01   85       2        2           1            1        1
# 3      Y09H151329P01   34       2        1           1            3        1
# 4      Y09H151325P01   68       1        2           1            3        2
# ...              ...  ...     ...      ...         ...          ...      ...
# 41539  Y09H260722P01   64       2        2           1            5        1
# 41540  Y09H260701P02   50       2        1           1            3        2
# 41541  Y09H260701P01   52       1        1           1            3        2
# 41542  Y09H260724P02   34       2        1           1            3        2
# 41543  Y09H260724P01   34       1        1           1            3        2
#
#        HHINC_grp  SA1_code  PopDensity_SA1  SA2_code  PopDensity_SA2  \
# 0              1   2100106            1500     21001             158
# 1              1   2100108             703     21001             158
# 2              1   2100108             703     21001             158
# 3              3   2100108             703     21001             158
# 4              3   2100108             703     21001             158
# ...          ...       ...             ...       ...             ...
# 41539          3   3144427             947     31444              88
# 41540          5   3144427             947     31444              88
# 41541          5   3144427             947     31444              88
# 41542          4   3144428              57     31444              88
# 41543          4   3144428              57     31444              88
#
#        SA3_code  PopDensity_SA3       STATE  ACTIVE_TRAVEL_TIME  CAR_TIME  \
# 0         20101             213    Victoria                   0        35
# 1         20101             213    Victoria                   0       100
# 2         20101             213    Victoria                   0        35
# 3         20101             213    Victoria                   0        79
# 4         20101             213    Victoria                   0        97
# ...         ...             ...         ...                 ...       ...
# 41539     31606              30  Queensland                   0        77
# 41540     31606              30  Queensland                   0        42
# 41541     31606              30  Queensland                   0        60
# 41542     31606              30  Queensland                   0        70
# 41543     31606              30  Queensland                   0        60
#
#         longitude   latitude
# 0      143.779310 -37.523063
# 1      143.779310 -37.523063
# 2      143.779310 -37.523063
# 3      143.779310 -37.523063
# 4      143.779310 -37.523063
# ...           ...        ...
# 41539  152.941689 -26.655579
# 41540  152.941689 -26.655579
# 41541  152.941689 -26.655579
# 41542  152.941689 -26.655579
# 41543  152.941689 -26.655579
#
# [41544 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41544 entries, 0 to 41543
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PERSONID            41544 non-null  object
#  1   AGE                 41544 non-null  int64
#  2   GENDER              41544 non-null  int64
#  3   ANYWORK             41544 non-null  int64
#  4   CARLICENCE          41544 non-null  int64
#  5   HHSTRUCTURE         41544 non-null  int64
#  6   HH_CARS             41544 non-null  int64
#  7   HHINC_grp           41544 non-null  int64
#  8   SA1_code            41544 non-null  int64
#  9   PopDensity_SA1      41544 non-null  int64
#  10  SA2_code            41544 non-null  int64
#  11  PopDensity_SA2      41544 non-null  int64
#  12  SA3_code            41544 non-null  int64
#  13  PopDensity_SA3      41544 non-null  int64
#  14  STATE               41544 non-null  object
#  15  ACTIVE_TRAVEL_TIME  41544 non-null  int64
#  16  CAR_TIME            41544 non-null  int64
#  17  longitude           41544 non-null  float64
#  18  latitude            41544 non-null  float64
# dtypes: float64(2), int64(15), object(2)
# memory usage: 6.0+ MB

# %%
########## Dropping record with the active travel time and car time = 0

#df = df.drop(df[(df['ACTIVE_TRAVEL_TIME'] == 0) & (df['CAR_TIME'] == 0)].index)

# %%
df
# Out:
#             PERSONID  AGE  GENDER  ANYWORK  CARLICENCE  HHSTRUCTURE  HH_CARS  \
# 0      Y09H151315P01   40       2        1           1            4        0
# 1      Y09H151324P01   73       1        2           1            2        1
# 2      Y09H151340P01   85       2        2           1            1        1
# 3      Y09H151329P01   34       2        1           1            3        1
# 4      Y09H151325P01   68       1        2           1            3        2
# ...              ...  ...     ...      ...         ...          ...      ...
# 41539  Y09H260722P01   64       2        2           1            5        1
# 41540  Y09H260701P02   50       2        1           1            3        2
# 41541  Y09H260701P01   52       1        1           1            3        2
# 41542  Y09H260724P02   34       2        1           1            3        2
# 41543  Y09H260724P01   34       1        1           1            3        2
#
#        HHINC_grp  SA1_code  PopDensity_SA1  SA2_code  PopDensity_SA2  \
# 0              1   2100106            1500     21001             158
# 1              1   2100108             703     21001             158
# 2              1   2100108             703     21001             158
# 3              3   2100108             703     21001             158
# 4              3   2100108             703     21001             158
# ...          ...       ...             ...       ...             ...
# 41539          3   3144427             947     31444              88
# 41540          5   3144427             947     31444              88
# 41541          5   3144427             947     31444              88
# 41542          4   3144428              57     31444              88
# 41543          4   3144428              57     31444              88
#
#        SA3_code  PopDensity_SA3       STATE  ACTIVE_TRAVEL_TIME  CAR_TIME  \
# 0         20101             213    Victoria                   0        35
# 1         20101             213    Victoria                   0       100
# 2         20101             213    Victoria                   0        35
# 3         20101             213    Victoria                   0        79
# 4         20101             213    Victoria                   0        97
# ...         ...             ...         ...                 ...       ...
# 41539     31606              30  Queensland                   0        77
# 41540     31606              30  Queensland                   0        42
# 41541     31606              30  Queensland                   0        60
# 41542     31606              30  Queensland                   0        70
# 41543     31606              30  Queensland                   0        60
#
#         longitude   latitude
# 0      143.779310 -37.523063
# 1      143.779310 -37.523063
# 2      143.779310 -37.523063
# 3      143.779310 -37.523063
# 4      143.779310 -37.523063
# ...           ...        ...
# 41539  152.941689 -26.655579
# 41540  152.941689 -26.655579
# 41541  152.941689 -26.655579
# 41542  152.941689 -26.655579
# 41543  152.941689 -26.655579
#
# [41544 rows x 19 columns]

# %%
# Assigning names to the numbers

# %%
df.drop(['PERSONID'], axis = 1, inplace = True)
#df.loc[(df.GENDER == 1),"GENDER"] = "MALE"
#df.loc[(df.GENDER == 2),"GENDER"] = "FEMALE"
#df.loc[(df.ANYWORK == 1),"ANYWORK"] = "YES"
#df.loc[(df.ANYWORK == 2),"ANYWORK"] = "NO"
#df.loc[(df.CARLICENCE == 1),"CARLICENCE"] = "YES"
#df.loc[(df.CARLICENCE == 2),"CARLICENCE"] = "NO"
df.loc[(df.STATE == 'Victoria'),"STATE"] = 1
df.loc[(df.STATE == 'Queensland'),"STATE"] = 2

# %%
df.query("ACTIVE_TRAVEL_TIME == CAR_TIME")
# Out:
#        AGE  GENDER  ANYWORK  CARLICENCE  HHSTRUCTURE  HH_CARS  HHINC_grp  \
# 190     75       1        2           1            1        1          1
# 405     31       2        2           1            2        2          4
# 426     28       1        1           1            5        2          5
# 571     65       1        2           1            2        1          2
# 625     84       1        2           1            4        2          2
# ...    ...     ...      ...         ...          ...      ...        ...
# 41376   62       2        1           1            2        2          1
# 41433   77       1        2           1            2        1          2
# 41445   74       2        2           2            2        1          2
# 41525   46       1        1           1            3        2          4
# 41535   36       2        1           1            3        2          5
#
#        SA1_code  PopDensity_SA1  SA2_code  PopDensity_SA2  SA3_code  \
# 190     2100224            1417     21002             975     20101
# 405     2100315             968     21003             238     20101
# 426     2100319             714     21003             238     20101
# 571     2100341            1995     21003             238     20101
# 625     2100349            1817     21003             238     20101
# ...         ...             ...       ...             ...       ...
# 41376   3144229             171     31442              71     31606
# 41433   3144302             917     31443              11     31606
# 41445   3144302             917     31443              11     31606
# 41525   3144427             947     31444              88     31606
# 41535   3144427             947     31444              88     31606
#
#        PopDensity_SA3 STATE  ACTIVE_TRAVEL_TIME  CAR_TIME   longitude  \
# 190               213     1                  45        45  143.826584
# 405               213     1                  30        30  143.922124
# 426               213     1                  10        10  143.922124
# 571               213     1                  20        20  143.922124
# 625               213     1                  20        20  143.922124
# ...               ...   ...                 ...       ...         ...
# 41376              30     2                  15        15  153.061473
# 41433              30     2                  10        10  152.767206
# 41445              30     2                  10        10  152.767206
# 41525              30     2                   0         0  152.941689
# 41535              30     2                  30        30  152.941689
#
#         latitude
# 190   -37.540579
# 405   -37.474392
# 426   -37.474392
# 571   -37.474392
# 625   -37.474392
# ...          ...
# 41376 -26.728274
# 41433 -26.468398
# 41445 -26.468398
# 41525 -26.655579
# 41535 -26.655579
#
# [433 rows x 18 columns]

# %% [markdown]
# ### We have 234 records with same active and car time and when combined with 0-0 its 433

# %%
bins=[18, 29, 39, 49, 59, 69, 79, 89, 101]

# labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70-79','80-89','90 +']

labels = [1,2,3,4,5,6,7,8]
df['AGE_RANGE'] = pd.cut(df['AGE'],bins,labels = labels, include_lowest = True)

# %%
df
# Out:
#        AGE  GENDER  ANYWORK  CARLICENCE  HHSTRUCTURE  HH_CARS  HHINC_grp  \
# 0       40       2        1           1            4        0          1
# 1       73       1        2           1            2        1          1
# 2       85       2        2           1            1        1          1
# 3       34       2        1           1            3        1          3
# 4       68       1        2           1            3        2          3
# ...    ...     ...      ...         ...          ...      ...        ...
# 41539   64       2        2           1            5        1          3
# 41540   50       2        1           1            3        2          5
# 41541   52       1        1           1            3        2          5
# 41542   34       2        1           1            3        2          4
# 41543   34       1        1           1            3        2          4
#
#        SA1_code  PopDensity_SA1  SA2_code  PopDensity_SA2  SA3_code  \
# 0       2100106            1500     21001             158     20101
# 1       2100108             703     21001             158     20101
# 2       2100108             703     21001             158     20101
# 3       2100108             703     21001             158     20101
# 4       2100108             703     21001             158     20101
# ...         ...             ...       ...             ...       ...
# 41539   3144427             947     31444              88     31606
# 41540   3144427             947     31444              88     31606
# 41541   3144427             947     31444              88     31606
# 41542   3144428              57     31444              88     31606
# 41543   3144428              57     31444              88     31606
#
#        PopDensity_SA3 STATE  ACTIVE_TRAVEL_TIME  CAR_TIME   longitude  \
# 0                 213     1                   0        35  143.779310
# 1                 213     1                   0       100  143.779310
# 2                 213     1                   0        35  143.779310
# 3                 213     1                   0        79  143.779310
# 4                 213     1                   0        97  143.779310
# ...               ...   ...                 ...       ...         ...
# 41539              30     2                   0        77  152.941689
# 41540              30     2                   0        42  152.941689
# 41541              30     2                   0        60  152.941689
# 41542              30     2                   0        70  152.941689
# 41543              30     2                   0        60  152.941689
#
#         latitude AGE_RANGE
# 0     -37.523063         3
# 1     -37.523063         6
# 2     -37.523063         7
# 3     -37.523063         2
# 4     -37.523063         5
# ...          ...       ...
# 41539 -26.655579         5
# 41540 -26.655579         4
# 41541 -26.655579         4
# 41542 -26.655579         2
# 41543 -26.655579         2
#
# [41544 rows x 19 columns]

# %% [markdown]
# ## Clustering

# %%
df_cluster = df.copy()

# %%
from sklearn import preprocessing

# %%
x = df[['GENDER','ANYWORK','AGE_RANGE','HHINC_grp','HHSTRUCTURE','HH_CARS','ACTIVE_TRAVEL_TIME','CAR_TIME']].copy()

# %%
#x = df_cluster.iloc[:,14:16]
#x

# %%
#x_scaled = preprocessing.scale(x)

# %%
from sklearn.cluster import KMeans

# %%
df33
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f07730912de8> in <module>
# ----> 1 df33
#
# NameError: name 'df33' is not defined

# %%
wcss = []

for i in range(1,20):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

# %%
#wcss

# %%
#The elbow method
number_clusters = range(1,20)
plt.plot(number_clusters,wcss)
plt.title("The elbow method")
plt.xlabel("Number of clusters")
plt.ylabel("Sum sq")

# %%
n_clusters = 3

# %%
kmeans = KMeans(n_clusters = n_clusters, init='k-means++', n_init = 10 ,max_iter=300,tol=0.0001,  random_state= 111  , algorithm='elkan')

# %%
#kmeans.fit(x_scaled)
kmeans.fit(x)
# Out:
# KMeans(algorithm='elkan', n_clusters=3, random_state=111)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([0, 2, 0, ..., 2, 2, 2])

# %%
data_with_clusters = x.copy()
data_with_clusters['cluster'] = identified_clusters
#centroids = pd.DataFrame(kmeans.cluster_centers_,columns=["ACTIVE_TRAVEL_TIME","CAR_TIME"])
#data_with_clusters

# %%
data_with_clusters.cluster.unique()
# Out:
# array([0, 2, 1])

# %%
#from sklearn.preprocessing import LabelEncoder
#encode = LabelEncoder()
#encode.fit(data_with_clusters['STATE'])
#data_with_clusters['STATE'] = encode.transform(data_with_clusters['STATE'])

# %%
df33

# %%
group = data_with_clusters.query("cluster == 2")
group
# Out:
#        GENDER  ANYWORK AGE_RANGE  HHINC_grp  HHSTRUCTURE  HH_CARS  \
# 1           1        2         6          1            2        1
# 3           2        1         2          3            3        1
# 4           1        2         5          3            3        2
# 6           2        1         2          4            3        2
# 12          2        1         1          5            5        2
# ...       ...      ...       ...        ...          ...      ...
# 41538       2        1         3          4            3        2
# 41539       2        2         5          3            5        1
# 41541       1        1         4          5            3        2
# 41542       2        1         2          4            3        2
# 41543       1        1         2          4            3        2
#
#        ACTIVE_TRAVEL_TIME  CAR_TIME  cluster
# 1                       0       100        2
# 3                       0        79        2
# 4                       0        97        2
# 6                       0       132        2
# 12                      0        65        2
# ...                   ...       ...      ...
# 41538                   0        65        2
# 41539                   0        77        2
# 41541                   0        60        2
# 41542                   0        70        2
# 41543                   0        60        2
#
# [14569 rows x 9 columns]

# %%
groupstat = group[['ACTIVE_TRAVEL_TIME','CAR_TIME']].copy()

# %%
groupstat.describe()
# Out:
#        ACTIVE_TRAVEL_TIME      CAR_TIME
# count        14569.000000  14569.000000
# mean             3.084220     88.285744
# std             12.422996     24.552004
# min              0.000000     56.000000
# 25%              0.000000     67.000000
# 50%              0.000000     84.000000
# 75%              0.000000    105.000000
# max            345.000000    148.000000

# %%
group.HH_CARS.value_counts()
# Out:
# 2    9974
# 1    4365
# 0     230
# Name: HH_CARS, dtype: int64

# %%
data_with_clusters.describe()
# Out:
#              GENDER       ANYWORK     HHINC_grp   HHSTRUCTURE      HH_CARS  \
# count  41544.000000  41544.000000  41544.000000  41544.000000  41544.00000
# mean       1.520075      1.250963      3.394714      2.754598      1.57681
# std        0.499603      0.433572      1.361040      1.064028      0.56639
# min        1.000000      1.000000      1.000000      1.000000      0.00000
# 25%        1.000000      1.000000      2.000000      2.000000      1.00000
# 50%        2.000000      1.000000      4.000000      3.000000      2.00000
# 75%        2.000000      2.000000      5.000000      3.000000      2.00000
# max        2.000000      2.000000      5.000000      5.000000      2.00000
#
#        ACTIVE_TRAVEL_TIME      CAR_TIME       cluster
# count        41544.000000  41544.000000  41544.000000
# mean             8.159831     60.881331      0.774841
# std             21.057916     57.498221      0.935874
# min              0.000000      0.000000      0.000000
# 25%              0.000000     20.000000      0.000000
# 50%              0.000000     46.000000      0.000000
# 75%              0.000000     83.000000      2.000000
# max            495.000000    780.000000      2.000000

# %%
plt.figure(figsize=(15,12))

scatter = plt.scatter(data_with_clusters['ACTIVE_TRAVEL_TIME'], data_with_clusters['CAR_TIME'] ,cmap="rainbow",c= data_with_clusters['cluster'],edgecolors='none')
plt.xlabel('Active Travel Time in Minute'), plt.ylabel('Car Travel Time in Minute') 
classes = ['Group 1', 'Group 2', 'Group 3', 'Group 4','Group 5','Group 6']
rangex = list(range(0,550,50))
rangey = list(range(0,850,50))
plt.xticks(rangex)
plt.yticks(rangey)

#plt.xlim(l100)
#plt.legend(*scatter.legend_elements())
plt.legend(handles = scatter.legend_elements()[0],labels = classes)
plt.show()

# %%
centroid = kmeans.cluster_centers_
centroid
# Out:
# array([[  1.53409423,   1.29846565,   3.31652661,   3.25021949,
#           2.72339981,   1.50892596,  11.90802291,  25.36886994],
#        [  1.43184797,   1.17332896,   3.20052425,   3.69888598,
#           2.73394495,   1.66939712,   2.98001311, 208.3810616 ],
#        [  1.51554244,   1.1892541 ,   3.09963631,   3.56817402,
#           2.81012832,   1.66883963,   3.09263707,  88.27811707]])

# %%
target_cluster = data_with_clusters.cluster

# %%
target_cluster.unique()
# Out:
# array([0, 2, 1])

# %%
df2 = data_with_clusters[['GENDER','ANYWORK','AGE_RANGE','HHINC_grp','HHSTRUCTURE','HH_CARS','ACTIVE_TRAVEL_TIME','CAR_TIME']].copy()

# %%
df2
# Out:
#        GENDER  ANYWORK AGE_RANGE  HHINC_grp  HHSTRUCTURE  HH_CARS  \
# 0           2        1         3          1            4        0
# 1           1        2         6          1            2        1
# 2           2        2         7          1            1        1
# 3           2        1         2          3            3        1
# 4           1        2         5          3            3        2
# ...       ...      ...       ...        ...          ...      ...
# 41539       2        2         5          3            5        1
# 41540       2        1         4          5            3        2
# 41541       1        1         4          5            3        2
# 41542       2        1         2          4            3        2
# 41543       1        1         2          4            3        2
#
#        ACTIVE_TRAVEL_TIME  CAR_TIME
# 0                       0        35
# 1                       0       100
# 2                       0        35
# 3                       0        79
# 4                       0        97
# ...                   ...       ...
# 41539                   0        77
# 41540                   0        42
# 41541                   0        60
# 41542                   0        70
# 41543                   0        60
#
# [41544 rows x 8 columns]

# %%
from sklearn.decomposition import PCA

# %%
#exlain variance

pca = PCA().fit(df2)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
plt.show()

# %%
pca = PCA(n_components = 2)
pca.fit_transform(df2)
print(pca.explained_variance_ratio_)
# Out:
# [0.88674068 0.11159711]

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
pca_components=pd.DataFrame(columns=['pca'])
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pcs = pca.fit_transform(df2)
df_new = pd.DataFrame(data=pcs, columns={'PC1','PC2'})
df_new['target'] = target_cluster
df_new.head()
# Out:
#          PC1        PC2  target
# 0 -25.035960 -10.491657       0
# 1  39.688889  -4.564570       2
# 2 -25.040450 -10.507414       0
# 3  18.787807  -6.464525       2
# 4  36.710235  -4.834377       2

# %%
plt.figure(figsize=(15,12))

scatter = plt.scatter(df_new['PC1'], df_new['PC2'] ,cmap="rainbow",c= df_new['target'],edgecolors='none')
plt.xlabel('PC1'), plt.ylabel('PC2') 
#classes = ['MALE','FEMALE']
#classes = [1,2,3,4,5,6,7,8]
classes = ['Group1','Group2','Group3']
plt.legend(handles = scatter.legend_elements()[0],labels = classes)
plt.title("Distribution")
plt.show()

# %% [markdown]
# # Stats

# %%
pd.set_option('float_format', '{:f}'.format)

# %%
df_new.describe()
# Out:
#                PC1          PC2       target
# count 41544.000000 41544.000000 41544.000000
# mean     -0.000000    -0.000000     0.774841
# std      57.709665    20.472775     0.935874
# min     -97.349179   -13.705809     0.000000
# 25%     -39.959571   -10.486077     0.000000
# 50%     -15.061231    -7.288656     0.000000
# 75%      22.763125     0.487157     2.000000
# max     716.858506   497.231360     2.000000

# %%
n = 4.154400e+04
format(n, 'f')
# Out:
# '41544.000000'

# %%
grp.AGE_RANGE.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-892b673990ba> in <module>
# ----> 1 grp.AGE_RANGE.value_counts()
#
# NameError: name 'grp' is not defined

# %%
df33

# %%
df = pd.concat([df1, df_new], axis=1)

# %%
df['cluster']= df1['cluster']

# %%
df

# %%
#df_active = pd.DataFrame(df.groupby(['cluster'])['PC1','PC2'].mean())

# %%
group1 = df.query("cluster == 0")

# %%
group1

# %%
group1 = group1[['PC1','PC2','GENDER']].copy()

# %%
group1

# %%
plt.figure(figsize=(15,12))

scatter = plt.scatter(group1['PC1'], group1['PC2'] ,cmap="rainbow",c= group1['GENDER'],edgecolors='none')
plt.xlabel('PC1'), plt.ylabel('PC2') 
classes = ['MALE','FEMALE']
#classes = [1,2,3,4,5,6,7,8]
#classes = ['Group1','Group2','Group3']
plt.legend(handles = scatter.legend_elements()[0],labels = classes)
plt.title("GENDER")
plt.show()

# %%
#df33

# %%
#df_new.target.unique()

# %%
#df_new

# %%
df

# %%
df33

# %%
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('test')
targets = [0,1,2]
colors = ['r','g','b']

plt.figure(figsize=(30,20))
classes = ['Mixed', 'Active', 'Sedentary']

for target, color in zip(targets,colors):
    indicesToKeep = data_with_clusters['cluster'] == target_cluster
    plt.scatter(df_new.loc[indicesToKeep, 'PC1'], df_new.loc[indicesToKeep, 'PC2'], cmap="rainbow",c= data_with_clusters['cluster'])

#plt.legend(targets,prop={'size': 15})

plt.legend(handles = scatter.legend_elements()[0],labels = classes)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="PC1", y="PC2",
    hue="target",
    #palette=sns.color_palette("hls", 2),
    data=df_new,
    #legend="target",
    alpha=0.3
)
